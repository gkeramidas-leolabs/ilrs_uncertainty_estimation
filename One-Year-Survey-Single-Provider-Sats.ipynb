# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
plt.style.use('ggplot')
plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.labelweight'] = 'heavy'
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['figure.titlesize'] = 12
plt.rcParams['text.usetex']=True

# %%
months = ["","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May"]

# %%
mlist = [x+1 for x in range(13)]

# %% [markdown]
# ## SARAL

# %%
filepath_sar = "/Users/gkeramidas/Projects/learning/L1471-SP-uncertainties.txt"

# %%
dx_sar = []
dy_sar = []
dz_sar = []

# %%
with open(filepath_sar,"r") as rf:
    next(rf)
    for columns in (raw.strip().split() for raw in rf):
        dx_sar.append(float(columns[1]))
        dy_sar.append(float(columns[2]))
        dz_sar.append(float(columns[3]))

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,5))
ax1.plot(mlist[:6],dx_sar[:6],"sb-")
ax1.plot(mlist[7:11],dx_sar[7:11],"sb-")
ax1.plot(mlist[-1:],dx_sar[-1:],"sb-")
ax2.plot(mlist[:6],dy_sar[:6],"sb-")
ax2.plot(mlist[7:11],dy_sar[7:11],"sb-")
ax2.plot(mlist[-1:],dy_sar[-1:],"sb-")
ax3.plot(mlist[:6],dz_sar[:6],"sb-")
ax3.plot(mlist[7:11],dz_sar[7:11],"sb-")
ax3.plot(mlist[-1:],dz_sar[-1:],"sb-")

ax1.set_ylabel(r"$\delta X$ (m)")
ax2.set_ylabel(r"$\delta Y$ (m)")
ax3.set_ylabel(r"$\delta Z$ (m)")
ax1.xaxis.set_major_locator(MaxNLocator(14))
ax1.set_xticklabels(months)
ax2.xaxis.set_major_locator(MaxNLocator(14))
ax2.set_xticklabels(months)
ax3.xaxis.set_major_locator(MaxNLocator(14))
ax3.set_xticklabels(months)
ax1.set_title("SARAL")
ax1.legend()
plt.show()
# Out:
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/3574909247.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/3574909247.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/3574909247.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(months)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
dz_sar[-1]
# Out:
# 68.78324050173754

# %% [markdown]
# ## CRYOSAT 2

# %%
filepath_cr = "/Users/gkeramidas/Projects/learning/L2669-SP-uncertainties.txt"

# %%
dx_cr = []
dy_cr = []
dz_cr = []

# %%
with open(filepath_cr,"r") as rf:
    next(rf)
    for columns in (raw.strip().split() for raw in rf):
        dx_cr.append(float(columns[1]))
        dy_cr.append(float(columns[2]))
        dz_cr.append(float(columns[3]))

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,5))
ax1.plot(mlist,dx_cr,"sb-")
ax2.plot(mlist,dy_cr,"sb-")
ax3.plot(mlist,dz_cr,"sb-")


ax1.set_ylabel(r"$\delta X$ (m)")
ax2.set_ylabel(r"$\delta Y$ (m)")
ax3.set_ylabel(r"$\delta Z$ (m)")
ax1.xaxis.set_major_locator(MaxNLocator(14))
ax1.set_xticklabels(months)
ax2.xaxis.set_major_locator(MaxNLocator(14))
ax2.set_xticklabels(months)
ax3.xaxis.set_major_locator(MaxNLocator(14))
ax3.set_xticklabels(months)
ax1.set_title("CRYOSAT 2")
ax1.legend()
plt.show()
# Out:
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/779291872.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/779291872.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/779291872.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(months)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
dz_cr[-1]
# Out:
# 84.80124068147808

# %% [markdown]
# ## SWARM A

# %%
filepath_swa = "/Users/gkeramidas/Projects/learning/L3972-SP-uncertainties.txt"

# %%
dx_swa = []
dy_swa = []
dz_swa = []

# %%
with open(filepath_swa,"r") as rf:
    next(rf)
    for columns in (raw.strip().split() for raw in rf):
        dx_swa.append(float(columns[1]))
        dy_swa.append(float(columns[2]))
        dz_swa.append(float(columns[3]))

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,5))
ax1.plot(mlist,dx_swa,"sb-")
ax2.plot(mlist,dy_swa,"sb-")
ax3.plot(mlist,dz_swa,"sb-")


ax1.set_ylabel(r"$\delta X$ (m)")
ax2.set_ylabel(r"$\delta Y$ (m)")
ax3.set_ylabel(r"$\delta Z$ (m)")
ax1.xaxis.set_major_locator(MaxNLocator(14))
ax1.set_xticklabels(months)
ax2.xaxis.set_major_locator(MaxNLocator(14))
ax2.set_xticklabels(months)
ax3.xaxis.set_major_locator(MaxNLocator(14))
ax3.set_xticklabels(months)
ax1.set_title("SWARM A")
ax1.legend()
plt.show()
# Out:
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/568816252.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/568816252.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/568816252.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(months)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
dz_swa[-1]
# Out:
# 1560.0823379883077

# %% [markdown]
# ## SWARM B

# %%
filepath_swb = "/Users/gkeramidas/Projects/learning/L5429-SP-uncertainties.txt"

# %%
dx_swb = []
dy_swb = []
dz_swb = []

# %%
with open(filepath_swb,"r") as rf:
    next(rf)
    for columns in (raw.strip().split() for raw in rf):
        dx_swb.append(float(columns[1]))
        dy_swb.append(float(columns[2]))
        dz_swb.append(float(columns[3]))

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,5))
ax1.plot(mlist,dx_swb,"sb-")
ax2.plot(mlist,dy_swb,"sb-")
ax3.plot(mlist,dz_swb,"sb-")


ax1.set_ylabel(r"$\delta X$ (m)")
ax2.set_ylabel(r"$\delta Y$ (m)")
ax3.set_ylabel(r"$\delta Z$ (m)")
ax1.xaxis.set_major_locator(MaxNLocator(14))
ax1.set_xticklabels(months)
ax2.xaxis.set_major_locator(MaxNLocator(14))
ax2.set_xticklabels(months)
ax3.xaxis.set_major_locator(MaxNLocator(14))
ax3.set_xticklabels(months)
ax1.set_title("SWARM B")
ax1.legend()
plt.show()
# Out:
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/2557972906.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/2557972906.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/2557972906.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(months)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
dz_swb[-1]
# Out:
# 259.8301598727936

# %% [markdown]
# ## SWARM C

# %%
filepath_swc = "/Users/gkeramidas/Projects/learning/L3969-SP-uncertainties.txt"

# %%
dx_swc = []
dy_swc = []
dz_swc = []

# %%
with open(filepath_swc,"r") as rf:
    next(rf)
    for columns in (raw.strip().split() for raw in rf):
        dx_swc.append(float(columns[1]))
        dy_swc.append(float(columns[2]))
        dz_swc.append(float(columns[3]))

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,5))
ax1.plot(mlist,dx_swc,"sb-")
ax2.plot(mlist,dy_swc,"sb-")
ax3.plot(mlist,dz_swc,"sb-")


ax1.set_ylabel(r"$\delta X$ (m)")
ax2.set_ylabel(r"$\delta Y$ (m)")
ax3.set_ylabel(r"$\delta Z$ (m)")
ax1.xaxis.set_major_locator(MaxNLocator(14))
ax1.set_xticklabels(months)
ax2.xaxis.set_major_locator(MaxNLocator(14))
ax2.set_xticklabels(months)
ax3.xaxis.set_major_locator(MaxNLocator(14))
ax3.set_xticklabels(months)
ax1.set_title("SWARM C")
ax1.legend()
plt.show()
# Out:
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/1891384193.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/1891384193.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/1891384193.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(months)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
dz_swc[-1]
# Out:
# 1679.9687624143437

# %% [markdown]
# ## ALL SWARMS

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,5))
ax1.plot(mlist,dx_swc,"sb-",label='SWARM C')
ax2.plot(mlist,dy_swc,"sb-",label='SWARM C')
ax3.plot(mlist,dz_swc,"sb-",label='SWARM C')
ax1.plot(mlist,dx_swa,"sr-",label='SWARM A')
ax2.plot(mlist,dy_swa,"sr-",label='SWARM A')
ax3.plot(mlist,dz_swa,"sr-",label='SWARM A')
ax1.plot(mlist,dx_swb,"sg-",label='SWARM B')
ax2.plot(mlist,dy_swb,"sg-",label='SWARM B')
ax3.plot(mlist,dz_swb,"sg-",label='SWARM B')


ax1.set_ylabel(r"$\delta X$ (m)")
ax2.set_ylabel(r"$\delta Y$ (m)")
ax3.set_ylabel(r"$\delta Z$ (m)")
ax1.xaxis.set_major_locator(MaxNLocator(14))
ax1.set_xticklabels(months)
ax2.xaxis.set_major_locator(MaxNLocator(14))
ax2.set_xticklabels(months)
ax3.xaxis.set_major_locator(MaxNLocator(14))
ax3.set_xticklabels(months)
ax1.set_title("SWARMS")
ax1.legend()
plt.show()
# Out:
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/3977909962.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/3977909962.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_86932/3977909962.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(months)
