# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
plt.style.use('ggplot')
plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.labelweight'] = 'heavy'
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['figure.titlesize'] = 12
plt.rcParams['text.usetex']=True

# %%
months = ["","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May"]

# %%
mlist = [x+1 for x in range(12)]

# %% [markdown]
# ## AJISAI

# %%
dx_aj_h = [5.589,5.283,6.3,4.099,4.555,2.998,4.14,1.47,0.984,1.28,3.649,3.667]
dx_aj_s = [5.5249,4.4618,4.84,3.411,4.94,3.46,3.5,1.75,1.4177,1.38,2.501,3.53]
dy_aj_h = [3.528,4.8699,5.11,4.776,4.126,4.716,3.2,1.83,1.062,1.886,2.635,3.19]
dy_aj_s = [3.556,4.008,4.608,5.123,3.86,4.1399,3.08,2.77,1.185,1.532,2.987,4.687]
dz_aj_h = [5.512,6.301,7.9368,5.676,5.558,4.9857,3.71,3.276,1.982,1.615,3.4979,5.00]
dz_aj_s = [5.72596,5.507,8.416,6.49,5.57,6.047,4.54,2.849,1.862,2.01,4.704,5.84]

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,5))
ax1.plot(mlist,dx_aj_h,"sb-",label="hts")
ax1.plot(mlist,dx_aj_s,"sr-",label="sgf")
ax2.plot(mlist,dy_aj_h,"sb-",label="hts")
ax2.plot(mlist,dy_aj_s,"sr-",label="sgf")
ax3.plot(mlist,dz_aj_h,"sb-",label="hts")
ax3.plot(mlist,dz_aj_s,"sr-",label="sgf")

ax1.set_ylabel(r"$\delta X$ (m)")
ax2.set_ylabel(r"$\delta Y$ (m)")
ax3.set_ylabel(r"$\delta Z$ (m)")
ax1.xaxis.set_major_locator(MaxNLocator(13))
ax1.set_xticklabels(months)
ax2.xaxis.set_major_locator(MaxNLocator(13))
ax2.set_xticklabels(months)
ax3.xaxis.set_major_locator(MaxNLocator(13))
ax3.set_xticklabels(months)
ax1.set_title("AJISAI")
ax1.legend()
plt.show()
# Out:
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_66788/2735514179.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_66788/2735514179.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_66788/2735514179.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(months)

# %% [markdown]
# ## LARETS

# %%
dx_lrt_h = [5.814,8.4998,9.741,8.322,13.57,5.569,5.39,5.21,4.22,4.834,15.34,7.20]
dx_lrt_s = [5.627,6.8089,7.586,9.454,6.92,5.09,5.51,6.809,6.10,8.155,19.18,7.959]
dy_lrt_h = [8.45,8.607,8.577,6.29,12.80,10.00,7.75,5.328,2.199,2.699,10.83,14.93]
dy_lrt_s = [9.59,8.967,8.929,6.48,6.20,8.05,7.64,4.345,1.79,4.172,15.14,17.14]
dz_lrt_h = [9.70,8.593,8.781,7.98,10.51,9.22,8.36,7.12,5.097,7.21,18.92,17.95]
dz_lrt_s = [9.48,9.478,9.71,7.72,10.92,9.74,7.76,7.108,5.58,6.472,20.32,16.94]

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,5))
ax1.plot(mlist,dx_lrt_h,"sb-",label="hts")
ax1.plot(mlist,dx_lrt_s,"sr-",label="sgf")
ax2.plot(mlist,dy_lrt_h,"sb-",label="hts")
ax2.plot(mlist,dy_lrt_s,"sr-",label="sgf")
ax3.plot(mlist,dz_lrt_h,"sb-",label="hts")
ax3.plot(mlist,dz_lrt_s,"sr-",label="sgf")

ax1.set_ylabel(r"$\delta X$ (m)")
ax2.set_ylabel(r"$\delta Y$ (m)")
ax3.set_ylabel(r"$\delta Z$ (m)")
ax1.xaxis.set_major_locator(MaxNLocator(13))
ax1.set_xticklabels(months)
ax2.xaxis.set_major_locator(MaxNLocator(13))
ax2.set_xticklabels(months)
ax3.xaxis.set_major_locator(MaxNLocator(13))
ax3.set_xticklabels(months)
ax1.set_title("LARETS")
ax1.legend()
plt.show()
# Out:
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_66788/1806269559.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_66788/1806269559.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_66788/1806269559.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(months)

# %% [markdown]
# ## LARES

# %%
dx_la_h = [7.409,4.83,6.838,4.83,6.679,4.615,3.79,2.458,1.617,1.768,4.011,5.85]
dx_la_s = [6.345,6.19,7.36,7.315,6.149,4.397,3.76,2.452,1.503,1.98,5.09,7.16]
dy_la_h = [6.197,8.299,7.718,5.46,6.504,5.796,3.93,2.202,1.872,2.42,3.638,4.22]
dy_la_s = [6.46,7.366,9.41,6.02,5.430,5.63,4.68,2.364,1.816,2.23,3.73,4.59]
dz_la_h = [7.286,6.069,9.725,8.94,8.70,7.327,5.33,3.303,2.199,2.82,4.23,6.48]
dz_la_s = [8.65,6.98,8.857,6.848,5.566,4.879,4.46,2.798,1.98,3.01,5.048,9.03]

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,5))
ax1.plot(mlist,dx_la_h,"sb-",label="hts")
ax1.plot(mlist,dx_la_s,"sr-",label="sgf")
ax2.plot(mlist,dy_la_h,"sb-",label="hts")
ax2.plot(mlist,dy_la_s,"sr-",label="sgf")
ax3.plot(mlist,dz_la_h,"sb-",label="hts")
ax3.plot(mlist,dz_la_s,"sr-",label="sgf")

ax1.set_ylabel(r"$\delta X$ (m)")
ax2.set_ylabel(r"$\delta Y$ (m)")
ax3.set_ylabel(r"$\delta Z$ (m)")
ax1.xaxis.set_major_locator(MaxNLocator(13))
ax1.set_xticklabels(months)
ax2.xaxis.set_major_locator(MaxNLocator(13))
ax2.set_xticklabels(months)
ax3.xaxis.set_major_locator(MaxNLocator(13))
ax3.set_xticklabels(months)
ax1.set_title("LARES")
ax1.legend()
plt.show()
# Out:
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_66788/4029730500.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_66788/4029730500.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_66788/4029730500.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(months)

# %% [markdown]
# ## STELLA

# %%
dx_st_h = [6.67,7.159,6.026,4.94,6.58,5.145,5.60,2.998,1.41,1.549,3.51,4.963]
dx_st_s = [8.42,8.469,6.484,4.719,5.93,5.173,6.53,1.873,1.188,1.638,4.06,6.6]
dy_st_h = [3.90,6.15,8.27,7.20,6.32,3.830,2.85,2.95,2.53,3.778,5.70,5.69]
dy_st_s = [3.997,6.94,8.92,9.638,5.74,3.80,3.11,2.25,2.036,3.10,4.33,4.837]
dz_st_h = [7.62,9.17,8.70,7.782,9.00,5.53,6.51,2.90,2.328,3.55,5.71,6.447]
dz_st_s = [6.57,7.16,7.55,6.766,7.90,5.12,5.13,2.42,2.5069,3.056,5.12,7.88]

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,5))
ax1.plot(mlist,dx_st_h,"sb-",label="hts")
ax1.plot(mlist,dx_st_s,"sr-",label="sgf")
ax2.plot(mlist,dy_st_h,"sb-",label="hts")
ax2.plot(mlist,dy_st_s,"sr-",label="sgf")
ax3.plot(mlist,dz_st_h,"sb-",label="hts")
ax3.plot(mlist,dz_st_s,"sr-",label="sgf")

ax1.set_ylabel(r"$\delta X$ (m)")
ax2.set_ylabel(r"$\delta Y$ (m)")
ax3.set_ylabel(r"$\delta Z$ (m)")
ax1.xaxis.set_major_locator(MaxNLocator(13))
ax1.set_xticklabels(months)
ax2.xaxis.set_major_locator(MaxNLocator(13))
ax2.set_xticklabels(months)
ax3.xaxis.set_major_locator(MaxNLocator(13))
ax3.set_xticklabels(months)
ax1.set_title("STELLA")
ax1.legend()
plt.show()
# Out:
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_66788/1916075139.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_66788/1916075139.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_66788/1916075139.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(months)

# %% [markdown]
# ## EXPLORER27

# %%
dx_ex_h = [11.869,12.97,19.67,10.33,34.86,25.67,24.38,11.4,12.38,33.257,13.86,9.90]
dx_ex_s = [8.36,11.73,9.81,13.08,17.76,12.88,21.46,13.794,13.059,34.96,13.52,15.37]
dy_ex_h = [9.84,12.41,11.15,15.31,27.2,20.28,31.45,17.52,11.86,32.55,13.6,9.338]
dy_ex_s = [11.31,10.83,13.86,12.444,19.82,12.41,24.26,12.69,9.019,30.02,11.50,11.98]
dz_ex_h = [10.51,11.14,12.89,12.61,11.60,15.83,17.869,11.45,6.681,26.14,9.65,8.44]
dz_ex_s = [10.46,13.82,14.44,17.467,29.22,12.49,17.95,9.80,10.14,24.14,13.08,11.55]

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,5))
ax1.plot(mlist,dx_ex_h,"sb-",label="hts")
ax1.plot(mlist,dx_ex_s,"sr-",label="sgf")
ax2.plot(mlist,dy_ex_h,"sb-",label="hts")
ax2.plot(mlist,dy_ex_s,"sr-",label="sgf")
ax3.plot(mlist,dz_ex_h,"sb-",label="hts")
ax3.plot(mlist,dz_ex_s,"sr-",label="sgf")

ax1.set_ylabel(r"$\delta X$ (m)")
ax2.set_ylabel(r"$\delta Y$ (m)")
ax3.set_ylabel(r"$\delta Z$ (m)")
ax1.xaxis.set_major_locator(MaxNLocator(13))
ax1.set_xticklabels(months)
ax2.xaxis.set_major_locator(MaxNLocator(13))
ax2.set_xticklabels(months)
ax3.xaxis.set_major_locator(MaxNLocator(13))
ax3.set_xticklabels(months)
ax1.set_title("EXPLORER 27")
ax1.legend()
plt.show()
# Out:
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_66788/2384026639.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_66788/2384026639.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(months)
# /var/folders/_2/q_y58n0d08305t24b4rr2_3m0000gn/T/ipykernel_66788/2384026639.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(months)

# %% [markdown]
# ## File write

# %%
from os.path import exists

# %%
leolabs_id="L5011"

# %%
filepath = "/Users/gkeramidas/Projects/learning/"+str(leolabs_id)+"uncertainties.txt"

# %%
if exists(filepath):
    pass
else:
    with open(filepath,"w") as f:
        f.write(str(leolabs_id) +"\t"+"dX1"+"\t"+"dY1"+"\t"+"dZ1"+"\n")

# %%
with open(filepath,"a") as f:
    for i in range(12):
        f.write(str(months[i+1])+"\t"+str(dx_st_h[i])+"\t"+str(dy_st_h[i])+"\t"+str(dz_st_h[i])+"\n")

# %%
dx_read = []
dy_read = []
dz_read = []

# %%
with open(filepath,"r") as rf:
    next(rf)
    for columns in (raw.strip().split() for raw in rf):
        dx_read.append(float(columns[1]))
        dy_read.append(float(columns[2]))
        dz_read.append(float(columns[3]))

# %%
dx_read
# Out:
# [6.67, 7.159, 6.026, 4.94, 6.58, 5.145, 5.6, 2.998, 1.41, 1.549, 3.51, 4.963]
